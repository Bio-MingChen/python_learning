# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# # Basic Graph

# %%
plot_global_setting = {
    'font.family': 'Comic Sans MS',
    'figure.figsize': (10, 5),
}

with plt.rc_context(plot_global_setting):
    x = np.arange(6)
    y = np.array([2*i for i in range(6)])
    plt.plot(x,y,color='red',linewidth=2,linestyle='--',marker='^',
            markersize=10,markeredgecolor='green',markerfacecolor='blue',
            label='2x')
    plt.plot(x,x**2,linestyle='-',marker='o',label='x^2')
    plt.title('Our first graph!', fontweight='bold', y=1.05,
            color='blue',loc='center',fontdict={'fontname':'Comic Sans MS', 'fontsize':20})

    plt.xlabel('X Axis', fontsize=15, fontweight='bold', color='green')
    plt.ylabel('Y Axis', fontsize=15, fontweight='bold', color='green')

    plt.xticks([0,1,2,3,4,5],['A','B','C','D','E','F'])
    # plt.yticks([0,2,4,6,8,10],['0','2','4','6','8','10'])

    plt.legend(['2x','x^2'], loc='upper right',bbox_to_anchor=(1.2,1))

    plt.tight_layout()  # 调整布局，防止内容被裁剪

    plt.savefig('firstGraph.png', dpi=300)
    plt.show()

# %%
np.linspace(0,10,10).reshape(5,2)
# Out:
# array([[ 0.        ,  1.11111111],
#        [ 2.22222222,  3.33333333],
#        [ 4.44444444,  5.55555556],
#        [ 6.66666667,  7.77777778],
#        [ 8.88888889, 10.        ]])

# %%
np.random.rand(5,4)
# Out:
# array([[0.51219675, 0.76239312, 0.35753363, 0.59689754],
#        [0.60927818, 0.56469456, 0.1256973 , 0.50152851],
#        [0.49423678, 0.43869719, 0.16357142, 0.53462663],
#        [0.08794306, 0.96820724, 0.65819843, 0.78388138],
#        [0.20587047, 0.15346906, 0.71411492, 0.77096951]])

# %%
np.random.uniform(1,10,(5,4))
# Out:
# array([[6.69194728, 7.70635193, 7.14113458, 1.70079782],
#        [7.44239354, 1.31808245, 4.15682597, 4.68589443],
#        [3.74018919, 9.16987092, 6.95778643, 2.87582023],
#        [4.1659013 , 7.74187094, 6.5569605 , 9.2422708 ],
#        [2.99916547, 8.55173157, 9.78054736, 1.67299982]])

# %%
plt.bar(np.random.randint(1,10,5),np.random.randint(1,10,5))
# Out:
# <BarContainer object of 5 artists>

# %%
plt.hist(np.random.randn(1000), bins=30, color='red', alpha=0.5)
# Out:
# (array([ 1.,  2.,  0.,  2.,  2.,  7., 12., 14., 13., 32., 41., 56., 52.,
#         81., 84., 78., 97., 67., 78., 63., 63., 49., 44., 24., 11., 12.,
#          6.,  6.,  1.,  2.]),
#  array([-3.56523343, -3.34734786, -3.12946228, -2.91157671, -2.69369113,
#         -2.47580556, -2.25791998, -2.04003441, -1.82214884, -1.60426326,
#         -1.38637769, -1.16849211, -0.95060654, -0.73272096, -0.51483539,
#         -0.29694982, -0.07906424,  0.13882133,  0.35670691,  0.57459248,
#          0.79247806,  1.01036363,  1.2282492 ,  1.44613478,  1.66402035,
#          1.88190593,  2.0997915 ,  2.31767708,  2.53556265,  2.75344822,
#          2.9713338 ]),
#  <BarContainer object of 30 artists>)
